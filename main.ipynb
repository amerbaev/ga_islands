# %%
from main import main
# %matplotlib inline
main()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 100000/100000 [1:12:14<00:00, 23.07it/s]
# [-10.9252, 1.1936] 0.0315230574255
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [01:36<00:00, 103.99it/s]
# [8.055, -9.6646] -19.2085025615
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [01:43<00:00, 96.22it/s]
# [-1.3494, 1.3494] -2.06261187081
